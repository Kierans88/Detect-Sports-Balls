# %%
# !pip install ultralytics

# %%
from google.colab import files

# Prompt user to upload a folder
uploaded = files.upload()

# Upload data set
# Upload .yaml file

# %%
# !unzip /content/dataset.zip

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=YOLO_dataset.yaml epochs=10 imgsz=640
# Out:
# Ultralytics 8.3.38 🚀 Python-3.11.10 torch-2.5.1+cpu CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# ...
